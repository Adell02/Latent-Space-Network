# %%
# %run main.py --mode visualize --run_dir original_w_gradient_ascent --keys 00d62c1b --n_values 2 --epoch 299
# Out:
# Using device: cuda
#
# Visualizing stored results...
#
# Visualizing training results...
# Plotting training progress and latent space...
# Plotting latent space analysis...
# Plotting epoch accuracies over time...
# Plotting reconstructions...
# Visualizing evaluation results...
# E:\GitCode\Latent-Space-Network\utils\visualizers.py:354: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(keys, rotation=45)
# E:\GitCode\Latent-Space-Network\utils\visualizers.py:354: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(keys, rotation=45)
# E:\GitCode\Latent-Space-Network\utils\visualizers.py:354: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(keys, rotation=45)
# ...
